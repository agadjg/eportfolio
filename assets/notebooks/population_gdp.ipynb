# %% [markdown]
# ## Population - GDP data analysis
#
# **Datasets:** Provided by the university
# * Global_Population.csv
# * Global_GDP.csv
#
# **Task A: Correlation**
# 1. Pre-process the data – mean population of each country and mean per capita GDP (from 2001 to 2021) by making some arrangements for the missing values.
# 2. Investigate any correlation between the mean population of each country and the mean per capita GDP (from 2001 to 2021). Very briefly, interpret the generated plot.
# 3. Evaluate the Pearson Correlation Coefficient.
#
# **Task B: Regression**
#
# Perform linear regression, where the independent variable is the mean population of each country (from 2001 to 2021) and dependent variable is mean per capita GDP (from 2001 to 2021).

# %% [markdown]
# ### Importing packages

# %%
#Import packages
import matplotlib.pyplot as plt
import pandas as pd
import pylab as pl
import numpy as np
import seaborn as sns

# %% [markdown]
# ### Loading datasets

# %%
#Load  both dataset
population = pd.read_csv("data/Global_Population.csv")
gdp = pd.read_csv("data/Global_GDP.csv")

# %% [markdown]
# ### Data Overview: Population

# %%
# Quick view of the population dataset
population.head()
# Out:
#                   Country Name Country Code        Series Name  Series Code  \
# 0                        Aruba          ABW  Population, total  SP.POP.TOTL
# 1                  Afghanistan          AFG  Population, total  SP.POP.TOTL
# 2  Africa Eastern and Southern          AFE  Population, total  SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total  SP.POP.TOTL
# 4                      Albania          ALB  Population, total  SP.POP.TOTL
#
#         1960       1961       1962       1963       1964       1965  ...  \
# 0      54211      55438      56225      56695      57032      57360  ...
# 1    8996967    9169406    9351442    9543200    9744772    9956318  ...
# 2  130836765  134159786  137614644  141202036  144920186  148769974  ...
# 3   96396419   98407221  100506960  102691339  104953470  107289875  ...
# 4    1608800    1659800    1711319    1762621    1814135    1864791  ...
#
#         2012       2013       2014       2015       2016       2017  \
# 0     102560     103159     103774     104341     104872     105366
# 1   31161378   32269592   33370804   34413603   35383028   36296111
# 2  547482863  562601578  578075373  593871847  609978946  626392880
# 3  370243017  380437896  390882979  401586651  412551299  423769930
# 4    2900401    2895092    2889104    2880703    2876101    2873457
#
#         2018       2019       2020       2021
# 0     105845     106314        NaN        NaN
# 1   37171922   38041757   38928341   39835000
# 2  643090131  660046272  677243299  694664000
# 3  435229381  446911598  458803476  470898000
# 4    2866376    2854191    2837743    2832000
#
# [5 rows x 66 columns]

# %%
population.tail()
# Out:
#                                           Country Name Country Code  \
# 267                                                NaN          NaN
# 268                                                NaN          NaN
# 269                                                NaN          NaN
# 270  Data from database: Population estimates and p...          NaN
# 271                           Last Updated: 12/17/2021          NaN
#
#     Series Name Series Code 1960 1961 1962 1963 1964 1965  ... 2012 2013 2014  \
# 267         NaN         NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# 268         NaN         NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# 269         NaN         NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# 270         NaN         NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# 271         NaN         NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
#
#     2015 2016 2017 2018 2019 2020 2021
# 267  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 268  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 269  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 270  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 271  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 66 columns]

# %% [markdown]
# Country names have missing infromation but also mistakenly uploaded footer informatation. These should be removed one by one.

# %%
#Removing rows with missing countries
population = population.dropna(subset=['Country Name'])

# %%
#Removing footer information via indexes
population = population.drop(index=[270, 271])

# %%
#Validate 
population['Country Name'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# All non available and unidentified country names have been removed.

# %%
#Dataset dimensions
population.shape
# Out:
# (267, 66)

# %%
# 1.2 Variable types
population.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 267 entries, 0 to 266
# Data columns (total 66 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  267 non-null    object
#  1   Country Code  267 non-null    object
#  2   Series Name   267 non-null    object
#  3   Series Code   267 non-null    object
#  4   1960          267 non-null    object
#  5   1961          267 non-null    object
#  6   1962          267 non-null    object
#  7   1963          267 non-null    object
#  8   1964          267 non-null    object
#  9   1965          267 non-null    object
#  10  1966          267 non-null    object
#  11  1967          267 non-null    object
#  12  1968          267 non-null    object
#  13  1969          267 non-null    object
#  14  1970          267 non-null    object
#  15  1971          267 non-null    object
#  16  1972          267 non-null    object
#  17  1973          267 non-null    object
#  18  1974          267 non-null    object
#  19  1975          267 non-null    object
#  20  1976          267 non-null    object
#  21  1977          267 non-null    object
#  22  1978          267 non-null    object
#  23  1979          267 non-null    object
#  24  1980          267 non-null    object
#  25  1981          267 non-null    object
#  26  1982          267 non-null    object
#  27  1983          267 non-null    object
#  28  1984          267 non-null    object
#  29  1985          267 non-null    object
#  30  1986          267 non-null    object
#  31  1987          267 non-null    object
#  32  1988          267 non-null    object
#  33  1989          267 non-null    object
#  34  1990          267 non-null    object
#  35  1991          267 non-null    object
#  36  1992          267 non-null    object
#  37  1993          267 non-null    object
#  38  1994          267 non-null    object
#  39  1995          267 non-null    object
#  40  1996          267 non-null    object
#  41  1997          267 non-null    object
#  42  1998          267 non-null    object
#  43  1999          267 non-null    object
#  44  2000          267 non-null    object
#  45  2001          267 non-null    object
#  46  2002          267 non-null    object
#  47  2003          267 non-null    object
#  48  2004          267 non-null    object
#  49  2005          267 non-null    object
#  50  2006          267 non-null    object
#  51  2007          267 non-null    object
#  52  2008          267 non-null    object
#  53  2009          267 non-null    object
#  54  2010          267 non-null    object
#  55  2011          267 non-null    object
#  56  2012          267 non-null    object
#  57  2013          267 non-null    object
#  58  2014          267 non-null    object
#  59  2015          267 non-null    object
#  60  2016          267 non-null    object
#  61  2017          267 non-null    object
#  62  2018          267 non-null    object
#  63  2019          267 non-null    object
#  64  2020          266 non-null    object
#  65  2021          266 non-null    object
# dtypes: object(66)
# memory usage: 139.8+ KB

# %% [markdown]
# ### Data Quality Assessment - Population

# %%
#Missigness
population.isnull().sum()
# Out:
# Country Name    0
# Country Code    0
# Series Name     0
# Series Code     0
# 1960            0
#                ..
# 2017            0
# 2018            0
# 2019            0
# 2020            1
# 2021            1
# Length: 66, dtype: int64

# %%
# Duplicates values in the dataset
population.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Population data inspection:
# * 272 observations, 66 columns, all categorical
# * Year range 1960-2021, but 2 missing values identified for two recent years
# * Years are categorical and need to be convtered into nummerical to calulate the means
# * No duplicated values found

# %% [markdown]
# ### Deep dive into missingness and duplicates

# %%
#Check if duplicated countries exists
population[population.duplicated(subset=['Country Name'], keep=False)]
# Out:
#    Country Name Country Code        Series Name  Series Code   1960   1961  \
# 0         Aruba          ABW  Population, total  SP.POP.TOTL  54211  55438
# 13        Aruba          ABW  Population, total  SP.POP.TOTL  54208  55434
#
#      1962   1963   1964   1965  ...    2012    2013    2014    2015    2016  \
# 0   56225  56695  57032  57360  ...  102560  103159  103774  104341  104872
# 13  56234  56699  57029  57357  ...  102565  103165  103776  104339  104865
#
#       2017    2018    2019    2020    2021
# 0   105366  105845  106314     NaN     NaN
# 13  105361  105846  106310  106766  107000
#
# [2 rows x 66 columns]

# %%
#Check if duplicated country code exists
population[population.duplicated(subset=['Country Code'], keep=False)]
# Out:
#    Country Name Country Code        Series Name  Series Code   1960   1961  \
# 0         Aruba          ABW  Population, total  SP.POP.TOTL  54211  55438
# 13        Aruba          ABW  Population, total  SP.POP.TOTL  54208  55434
#
#      1962   1963   1964   1965  ...    2012    2013    2014    2015    2016  \
# 0   56225  56695  57032  57360  ...  102560  103159  103774  104341  104872
# 13  56234  56699  57029  57357  ...  102565  103165  103776  104339  104865
#
#       2017    2018    2019    2020    2021
# 0   105366  105845  106314     NaN     NaN
# 13  105361  105846  106310  106766  107000
#
# [2 rows x 66 columns]

# %% [markdown]
# Aruba was recorded twice, with the same country code and series name and code. Given marginal differences between the recorded values, and two missing years in 2020 and 2021, first Aruba observation will be droppped.

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Duplicated country

# %%
#Removing duplicated Aruba with missing values
population = population.drop(index=[0])

# %%
#Validate if only one correct Aruba is left
population[population['Country Name'] == 'Aruba']
# Out:
#    Country Name Country Code        Series Name  Series Code   1960   1961  \
# 13        Aruba          ABW  Population, total  SP.POP.TOTL  54208  55434
#
#      1962   1963   1964   1965  ...    2012    2013    2014    2015    2016  \
# 13  56234  56699  57029  57357  ...  102565  103165  103776  104339  104865
#
#       2017    2018    2019    2020    2021
# 13  105361  105846  106310  106766  107000
#
# [1 rows x 66 columns]

# %% [markdown]
# ### Year

# %% [markdown]
# Given that year values are stored as object we need to transform them into numerical values. First however, for easier preprocessing we are creating a 'years' object with year range 2001-2021 that are requiered for the analysis as a list to simplify conversion.
#
# Note: After inspecting GDP year range which is only until 2020, I am limiting population range to align with GDP.

# %%
#Create years object for easy years sorting
years = [str(year) for year in range(2001, 2021)]

# %%
#verify the age range
[col for col in years if col not in population.columns]
# Out:
# []

# %%
#First check missing values across the years
population[years].isnull().sum()
# Out:
# 2001    0
# 2002    0
# 2003    0
# 2004    0
# 2005    0
# 2006    0
# 2007    0
# 2008    0
# 2009    0
# 2010    0
# 2011    0
# 2012    0
# 2013    0
# 2014    0
# 2015    0
# 2016    0
# 2017    0
# 2018    0
# 2019    0
# 2020    0
# dtype: int64

# %% [markdown]
# No missing values were detected per year, but we need to check whether there are any non-numeric values available.

# %%
# Checking if all years values contain values that can not be converted to numbers.

for year in years:
    non_numeric = pd.to_numeric(population[year], errors='coerce').isna() & population[year].notna()

    if non_numeric.any():
        print(year)
        print(population.loc[non_numeric,['Country Name', year]])
# Out:
# 2001
#        Country Name 2001
# 106       IBRD only   ..
# 109       IDA blend   ..
# 110        IDA only   ..
# 111       IDA total   ..
# 184  Not classified   ..
# 2002
#        Country Name 2002
# 106       IBRD only   ..
# 109       IDA blend   ..
# 110        IDA only   ..
# 111       IDA total   ..
# 184  Not classified   ..
# 2003
#        Country Name 2003
# 106       IBRD only   ..
# 109       IDA blend   ..
# 110        IDA only   ..
# 111       IDA total   ..
# 184  Not classified   ..
# 2004
#        Country Name 2004
# 106       IBRD only   ..
# 109       IDA blend   ..
# 110        IDA only   ..
# 111       IDA total   ..
# 184  Not classified   ..
# 2005
#        Country Name 2005
# 106       IBRD only   ..
# 109       IDA blend   ..
# 110        IDA only   ..
# 111       IDA total   ..
# 184  Not classified   ..
# 2006
#        Country Name 2006
# 106       IBRD only   ..
# 109       IDA blend   ..
# 110        IDA only   ..
# 111       IDA total   ..
# 184  Not classified   ..
# 2007
#        Country Name 2007
# 106       IBRD only   ..
# 109       IDA blend   ..
# 110        IDA only   ..
# 111       IDA total   ..
# 184  Not classified   ..
# 2008
#        Country Name 2008
# 106       IBRD only   ..
# 109       IDA blend   ..
# 110        IDA only   ..
# 111       IDA total   ..
# 184  Not classified   ..
# 2009
#        Country Name 2009
# 106       IBRD only   ..
# 109       IDA blend   ..
# 110        IDA only   ..
# 111       IDA total   ..
# 184  Not classified   ..
# 2010
#        Country Name 2010
# 106       IBRD only   ..
# 109       IDA blend   ..
# 110        IDA only   ..
# 111       IDA total   ..
# 184  Not classified   ..
# 2011
#        Country Name 2011
# 106       IBRD only   ..
# 109       IDA blend   ..
# 110        IDA only   ..
# 111       IDA total   ..
# 184  Not classified   ..
# 2012
#        Country Name 2012
# 71          Eritrea   ..
# 106       IBRD only   ..
# 109       IDA blend   ..
# 110        IDA only   ..
# 111       IDA total   ..
# 184  Not classified   ..
# 2013
#        Country Name 2013
# 71          Eritrea   ..
# 106       IBRD only   ..
# 109       IDA blend   ..
# 110        IDA only   ..
# 111       IDA total   ..
# 184  Not classified   ..
# 2014
#        Country Name 2014
# 71          Eritrea   ..
# 106       IBRD only   ..
# 109       IDA blend   ..
# 110        IDA only   ..
# 111       IDA total   ..
# 184  Not classified   ..
# 2015
#        Country Name 2015
# 71          Eritrea   ..
# 106       IBRD only   ..
# 109       IDA blend   ..
# 110        IDA only   ..
# 111       IDA total   ..
# 184  Not classified   ..
# 2016
#        Country Name 2016
# 71          Eritrea   ..
# 106       IBRD only   ..
# 109       IDA blend   ..
# 110        IDA only   ..
# 111       IDA total   ..
# 184  Not classified   ..
# 2017
#        Country Name 2017
# 71          Eritrea   ..
# 106       IBRD only   ..
# 109       IDA blend   ..
# 110        IDA only   ..
# 111       IDA total   ..
# 184  Not classified   ..
# 2018
#        Country Name 2018
# 71          Eritrea   ..
# 106       IBRD only   ..
# 109       IDA blend   ..
# 110        IDA only   ..
# 111       IDA total   ..
# 184  Not classified   ..
# 2019
#        Country Name 2019
# 71          Eritrea   ..
# 106       IBRD only   ..
# 109       IDA blend   ..
# 110        IDA only   ..
# 111       IDA total   ..
# 184  Not classified   ..
# 2020
#        Country Name 2020
# 71          Eritrea   ..
# 106       IBRD only   ..
# 109       IDA blend   ..
# 110        IDA only   ..
# 111       IDA total   ..
# 184  Not classified   ..

# %% [markdown]
# The year column stored all values as object becuase the missing observations were represented as '..', hence we can proceed with converting these to NaN.  Also some countries have 'no country' values. Further investigation requiered before dropping them.

# %% [markdown]
# ### Converting the 2001–2020 columns

# %%
#Convert categorical years values into numerical values, values that could not be converted replace with NaN
population[years] = population[years].apply(pd.to_numeric, errors='coerce')

# %%
#Validation of the conversion
population[years].dtypes
# Out:
# 2001    float64
# 2002    float64
# 2003    float64
# 2004    float64
# 2005    float64
# 2006    float64
# 2007    float64
# 2008    float64
# 2009    float64
# 2010    float64
# 2011    float64
# 2012    float64
# 2013    float64
# 2014    float64
# 2015    float64
# 2016    float64
# 2017    float64
# 2018    float64
# 2019    float64
# 2020    float64
# dtype: object

# %%
#Check missing values per year
population[years].isnull().sum()
# Out:
# 2001    5
# 2002    5
# 2003    5
# 2004    5
# 2005    5
# 2006    5
# 2007    5
# 2008    5
# 2009    5
# 2010    5
# 2011    5
# 2012    6
# 2013    6
# 2014    6
# 2015    6
# 2016    6
# 2017    6
# 2018    6
# 2019    6
# 2020    6
# dtype: int64

# %%
#Affected countries with missing values
population.loc[population[years].isnull().any(axis=1), ['Country Name'] + ['Country Code'] + years]
# Out:
#        Country Name Country Code       2001       2002       2003       2004  \
# 71          Eritrea          ERI  2374721.0  2481059.0  2600972.0  2719809.0
# 106       IBRD only          IBD        NaN        NaN        NaN        NaN
# 109       IDA blend          IDB        NaN        NaN        NaN        NaN
# 110        IDA only          IDX        NaN        NaN        NaN        NaN
# 111       IDA total          IDA        NaN        NaN        NaN        NaN
# 184  Not classified          INX        NaN        NaN        NaN        NaN
#
#           2005       2006       2007       2008  ...       2011  2012  2013  \
# 71   2826653.0  2918209.0  2996540.0  3062782.0  ...  3213969.0   NaN   NaN
# 106        NaN        NaN        NaN        NaN  ...        NaN   NaN   NaN
# 109        NaN        NaN        NaN        NaN  ...        NaN   NaN   NaN
# 110        NaN        NaN        NaN        NaN  ...        NaN   NaN   NaN
# 111        NaN        NaN        NaN        NaN  ...        NaN   NaN   NaN
# 184        NaN        NaN        NaN        NaN  ...        NaN   NaN   NaN
#
#      2014  2015  2016  2017  2018  2019  2020
# 71    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 106   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 109   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 110   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 111   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 184   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [6 rows x 22 columns]

# %% [markdown]
# After conversion some odd countries and 'non classsified' turned out to have non available values. I want to inspect them to decide whether these should be removed.

# %%
#Checking suspicious country names 
all_missing = population[years].isna().all(axis=1)

population.loc[all_missing, ['Country Name']]
# Out:
#        Country Name
# 106       IBRD only
# 109       IDA blend
# 110        IDA only
# 111       IDA total
# 184  Not classified

# %% [markdown]
# Confirmed the odd countries have ALL missing values for year. Proceeding with removing them.

# %%
#Removing Countries with all missing values from 2001-2020
population = population.loc[~all_missing]

# %%
#Validate
population[years].isna().all(axis=1).sum()
# Out:
# np.int64(0)

# %% [markdown]
# Checking whether other countries are missing any year values

# %%
#Checking year missignsess across 2001-2020

any_missing = population[years].isna().any(axis=1)

population.loc[any_missing, ['Country Name'] + years]
# Out:
#    Country Name       2001       2002       2003       2004       2005  \
# 71      Eritrea  2374721.0  2481059.0  2600972.0  2719809.0  2826653.0
#
#          2006       2007       2008       2009  ...       2011  2012  2013  \
# 71  2918209.0  2996540.0  3062782.0  3119920.0  ...  3213969.0   NaN   NaN
#
#     2014  2015  2016  2017  2018  2019  2020
# 71   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [1 rows x 21 columns]

# %%
#Inspecting the missigness pattern

for _, row in population.loc[
    population[years].isna().any(axis=1)
].iterrows():

    missing_years = row[years][row[years].isna()].index.tolist()
    print(row["Country Name"], missing_years)
# Out:
# Eritrea ['2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020']

# %% [markdown]
# Decision: since only Eritrea misses 9 out of 20 values, I am exluding the country form the list.

# %%
# Droping Eritrea
population = population.drop(index=71)

# %%
#Verify
population[population['Country Name'] == 'Eritrea']
# Out:
# Empty DataFrame
# Columns: [Country Name, Country Code, Series Name, Series Code, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
# Index: []
#
# [0 rows x 66 columns]

# %%
#Saving cleaned preprocessed file
population.to_csv('Global_Population_Cleaned.csv', index=False)

# %% [markdown]
# ### Calculate mean population

# %%
# Calulate the mean population across 2001 -2020 
population['Mean Population'] = population[years].mean(axis=1, skipna=True)

# %%
#Inspect
population[['Country Name', 'Mean Population']].head()
# Out:
#                   Country Name  Mean Population
# 1                  Afghanistan     3.021299e+07
# 2  Africa Eastern and Southern     5.321282e+08
# 3   Africa Western and Central     3.594714e+08
# 4                      Albania     2.935900e+06
# 5                      Algeria     3.685864e+07

# %%
#Saving Mean Population file
mean_population = population[['Country Name', 'Mean Population']]

mean_population.to_csv('Mean_Population_2001_2020.csv', index=False)

# %%
mean_population.shape
# Out:
# (260, 2)

# %% [markdown]
# # Data Overview - GDP

# %%
# Quick view of the population dataset
gdp.head()
# Out:
#                   Country Name Country Code     Indicator Name  \
# 0                        Aruba          ABW  GDP (current US$)
# 1  Africa Eastern and Southern          AFE  GDP (current US$)
# 2                  Afghanistan          AFG  GDP (current US$)
# 3   Africa Western and Central          AFW  GDP (current US$)
# 4                       Angola          AGO  GDP (current US$)
#
#    Indicator Code          1960          1961          1962          1963  \
# 0  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
# 1  NY.GDP.MKTP.CD  1.929944e+10  1.970954e+10  2.147872e+10  2.571501e+10
# 2  NY.GDP.MKTP.CD  5.377778e+08  5.488889e+08  5.466667e+08  7.511112e+08
# 3  NY.GDP.MKTP.CD  1.040428e+10  1.112805e+10  1.194335e+10  1.267652e+10
# 4  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
#
#            1964          1965  ...          2011          2012          2013  \
# 0           NaN           NaN  ...  2.549721e+09  2.534637e+09  2.727850e+09
# 1  2.351080e+10  2.679160e+10  ...  9.427110e+11  9.498490e+11  9.635600e+11
# 2  8.000000e+08  1.006667e+09  ...  1.780511e+10  1.990732e+10  2.014640e+10
# 3  1.383858e+10  1.486247e+10  ...  6.709630e+11  7.275710e+11  8.207880e+11
# 4           NaN           NaN  ...  1.117900e+11  1.280530e+11  1.367100e+11
#
#            2014          2015          2016          2017          2018  \
# 0  2.790849e+09  2.962905e+09  2.983637e+09  3.092430e+09  3.202189e+09
# 1  9.837490e+11  9.186470e+11  8.720230e+11  9.842560e+11  1.011720e+12
# 2  2.049713e+10  1.913421e+10  1.811656e+10  1.875347e+10  1.805323e+10
# 3  8.514870e+11  7.607300e+11  6.905430e+11  6.837420e+11  7.416920e+11
# 4  1.457120e+11  1.161940e+11  1.011240e+11  1.221240e+11  1.013530e+11
#
#            2019          2020
# 0           NaN           NaN
# 1  1.008380e+12  9.188150e+11
# 2  1.879945e+10  2.011614e+10
# 3  7.945720e+11  7.845880e+11
# 4  8.941719e+10  5.837598e+10
#
# [5 rows x 65 columns]

# %%
gdp.tail()
# Out:
#      Country Name Country Code     Indicator Name  Indicator Code  \
# 261        Kosovo          XKX  GDP (current US$)  NY.GDP.MKTP.CD
# 262   Yemen, Rep.          YEM  GDP (current US$)  NY.GDP.MKTP.CD
# 263  South Africa          ZAF  GDP (current US$)  NY.GDP.MKTP.CD
# 264        Zambia          ZMB  GDP (current US$)  NY.GDP.MKTP.CD
# 265      Zimbabwe          ZWE  GDP (current US$)  NY.GDP.MKTP.CD
#
#              1960          1961          1962          1963          1964  \
# 261           NaN           NaN           NaN           NaN           NaN
# 262           NaN           NaN           NaN           NaN           NaN
# 263  7.575397e+09  7.972997e+09  8.497997e+09  9.423396e+09  1.037400e+10
# 264  7.130000e+08  6.962857e+08  6.931429e+08  7.187143e+08  8.394286e+08
# 265  1.052990e+09  1.096647e+09  1.117602e+09  1.159512e+09  1.217138e+09
#
#              1965  ...          2011          2012          2013  \
# 261           NaN  ...  6.341737e+09  6.163785e+09  6.735731e+09
# 262           NaN  ...  3.272642e+10  3.540134e+10  4.041524e+10
# 263  1.133440e+10  ...  4.582020e+11  4.344010e+11  4.008860e+11
# 264  1.082857e+09  ...  2.345952e+10  2.550306e+10  2.803724e+10
# 265  1.311436e+09  ...  1.410192e+10  1.711485e+10  1.909102e+10
#
#              2014          2015          2016          2017          2018  \
# 261  7.074658e+09  6.295820e+09  6.682833e+09  7.180813e+09  7.878509e+09
# 262  4.322859e+10  4.244510e+10  3.131737e+10  2.684013e+10  2.160614e+10
# 263  3.811990e+11  3.467100e+11  3.235860e+11  3.814490e+11  4.048420e+11
# 264  2.714102e+10  2.125122e+10  2.095841e+10  2.587360e+10  2.631159e+10
# 265  1.949552e+10  1.996312e+10  2.054868e+10  1.758489e+10  1.811554e+10
#
#              2019          2020
# 261  7.899879e+09  7.716925e+09
# 262           NaN           NaN
# 263  3.879350e+11  3.354420e+11
# 264  2.330867e+10  1.811063e+10
# 265  1.928429e+10  1.805117e+10
#
# [5 rows x 65 columns]

# %%
#Dataset dimensions
gdp.shape
# Out:
# (266, 65)

# %%
gdp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 65 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1960            128 non-null    float64
#  5   1961            134 non-null    float64
#  6   1962            137 non-null    float64
#  7   1963            137 non-null    float64
#  8   1964            137 non-null    float64
#  9   1965            148 non-null    float64
#  10  1966            151 non-null    float64
#  11  1967            154 non-null    float64
#  12  1968            159 non-null    float64
#  13  1969            159 non-null    float64
#  14  1970            168 non-null    float64
#  15  1971            171 non-null    float64
#  16  1972            171 non-null    float64
#  17  1973            171 non-null    float64
#  18  1974            172 non-null    float64
#  19  1975            174 non-null    float64
#  20  1976            175 non-null    float64
#  21  1977            178 non-null    float64
#  22  1978            177 non-null    float64
#  23  1979            178 non-null    float64
#  24  1980            190 non-null    float64
#  25  1981            194 non-null    float64
#  26  1982            195 non-null    float64
#  27  1983            196 non-null    float64
#  28  1984            197 non-null    float64
#  29  1985            199 non-null    float64
#  30  1986            201 non-null    float64
#  31  1987            205 non-null    float64
#  32  1988            210 non-null    float64
#  33  1989            210 non-null    float64
#  34  1990            225 non-null    float64
#  35  1991            220 non-null    float64
#  36  1992            224 non-null    float64
#  37  1993            227 non-null    float64
#  38  1994            231 non-null    float64
#  39  1995            240 non-null    float64
#  40  1996            240 non-null    float64
#  41  1997            240 non-null    float64
#  42  1998            242 non-null    float64
#  43  1999            243 non-null    float64
#  44  2000            247 non-null    float64
#  45  2001            248 non-null    float64
#  46  2002            253 non-null    float64
#  47  2003            253 non-null    float64
#  48  2004            253 non-null    float64
#  49  2005            253 non-null    float64
#  50  2006            254 non-null    float64
#  51  2007            254 non-null    float64
#  52  2008            255 non-null    float64
#  53  2009            255 non-null    float64
#  54  2010            256 non-null    float64
#  55  2011            258 non-null    float64
#  56  2012            257 non-null    float64
#  57  2013            258 non-null    float64
#  58  2014            258 non-null    float64
#  59  2015            257 non-null    float64
#  60  2016            256 non-null    float64
#  61  2017            256 non-null    float64
#  62  2018            256 non-null    float64
#  63  2019            253 non-null    float64
#  64  2020            241 non-null    float64
# dtypes: float64(61), object(4)
# memory usage: 135.2+ KB

# %% [markdown]
# ### Data Quality Assessment - GDP

# %%
gdp.isnull().sum()
# Out:
# Country Name        0
# Country Code        0
# Indicator Name      0
# Indicator Code      0
# 1960              138
#                  ...
# 2016               10
# 2017               10
# 2018               10
# 2019               13
# 2020               25
# Length: 65, dtype: int64

# %%
gdp.duplicated().sum()
# Out:
# np.int64(0)

# %%
#Check if duplicated countries exists
gdp[gdp.duplicated(subset=['Country Name'], keep=False)]
# Out:
# Empty DataFrame
# Columns: [Country Name, Country Code, Indicator Name, Indicator Code, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]
# Index: []
#
# [0 rows x 65 columns]

# %% [markdown]
# gdp data inspection:
# * 266 observations, 65 columns (missing 2021 year as opposed to population)
# * Years values are stored as numeric
# * A few missing values identified across year
# * No duplicated values found, no duplicated counturies found
# * Data unitl 2020 as opposed to population till 2021 for population

# %% [markdown]
# ### Year Preprocessing

# %%
#Check years range
years = [str(year) for year in range(2001, 2021)]

[col for col in years if col not in gdp.columns]
# Out:
# []

# %%
#Create years object for gdp 2001-2020
gdp_years = [str(year) for year in range(2001, 2021)]

# %%
#Check year type
gdp[gdp_years].dtypes
# Out:
# 2001    float64
# 2002    float64
# 2003    float64
# 2004    float64
# 2005    float64
# 2006    float64
# 2007    float64
# 2008    float64
# 2009    float64
# 2010    float64
# 2011    float64
# 2012    float64
# 2013    float64
# 2014    float64
# 2015    float64
# 2016    float64
# 2017    float64
# 2018    float64
# 2019    float64
# 2020    float64
# dtype: object

# %%
#First check missing values across the years
gdp[gdp_years].isnull().sum()
# Out:
# 2001    18
# 2002    13
# 2003    13
# 2004    13
# 2005    13
# 2006    12
# 2007    12
# 2008    11
# 2009    11
# 2010    10
# 2011     8
# 2012     9
# 2013     8
# 2014     8
# 2015     9
# 2016    10
# 2017    10
# 2018    10
# 2019    13
# 2020    25
# dtype: int64

# %% [markdown]
# All year values are stores as numeric, so no conversion is needed. However, values are missing across different years. Now checking affected countries.

# %%
#Affected countries with missing values
gdp.loc[gdp[gdp_years].isnull().any(axis=1), ['Country Name'] + ['Country Code'] + gdp_years]
# Out:
#                   Country Name Country Code          2001          2002  \
# 0                        Aruba          ABW  1.920112e+09  1.941341e+09
# 2                  Afghanistan          AFG           NaN  4.055180e+09
# 6                      Andorra          AND  1.546926e+09  1.755910e+09
# 11              American Samoa          ASM           NaN  5.120000e+08
# 38             Channel Islands          CHI  6.232906e+09  6.663669e+09
# 51                     Curacao          CUW           NaN           NaN
# 52              Cayman Islands          CYM           NaN           NaN
# 69                     Eritrea          ERI  7.523685e+08  7.293214e+08
# 78               Faroe Islands          FRO  1.147655e+09  1.262670e+09
# 84                   Gibraltar          GIB           NaN           NaN
# 91                   Greenland          GRL  1.086173e+09  1.169139e+09
# 93                        Guam          GUM           NaN  3.394000e+09
# 108                Isle of Man          IMN  1.659131e+09  1.947333e+09
# 110             Not classified          INX           NaN           NaN
# 137              Liechtenstein          LIE  2.491823e+09  2.688631e+09
# 147   St. Martin (French part)          MAF           NaN           NaN
# 149                     Monaco          MCO  2.718868e+09  2.968987e+09
# 164   Northern Mariana Islands          MNP           NaN  1.284000e+09
# 172              New Caledonia          NCL  3.297735e+09  3.740057e+09
# 179                      Nauru          NRU           NaN           NaN
# 193  Korea, Dem. People's Rep.          PRK           NaN           NaN
# 199           French Polynesia          PYF           NaN           NaN
# 212                 San Marino          SMR  1.077413e+09  1.168269e+09
# 213                    Somalia          SOM           NaN           NaN
# 216                South Sudan          SSD           NaN           NaN
# 225  Sint Maarten (Dutch part)          SXM           NaN           NaN
# 227       Syrian Arab Republic          SYR  8.677131e+10  9.055849e+10
# 235               Turkmenistan          TKM  3.534804e+09  4.461978e+09
# 254              Venezuela, RB          VEN  1.229040e+11  9.289359e+10
# 255     British Virgin Islands          VGB           NaN           NaN
# 256      Virgin Islands (U.S.)          VIR           NaN  3.262000e+09
# 261                     Kosovo          XKX           NaN           NaN
# 262                Yemen, Rep.          YEM  9.861560e+09  1.069463e+10
#
#              2003          2004          2005          2006          2007  \
# 0    2.021229e+09  2.228492e+09  2.330726e+09  2.424581e+09  2.615084e+09
# 2    4.515559e+09  5.226779e+09  6.209138e+09  6.971286e+09  9.747880e+09
# 6    2.361727e+09  2.894922e+09  3.159905e+09  3.456442e+09  3.952601e+09
# 11   5.240000e+08  5.090000e+08  5.000000e+08  4.930000e+08  5.180000e+08
# 38   7.332245e+09  8.553643e+09  8.827273e+09  9.676173e+09  1.151461e+10
# 51            NaN           NaN           NaN           NaN           NaN
# 52            NaN           NaN           NaN  4.200439e+09  4.466439e+09
# 69   8.702477e+08  1.109054e+09  1.098426e+09  1.211162e+09  1.317974e+09
# 78   1.494012e+09  1.688238e+09  1.727793e+09  1.984445e+09  2.290134e+09
# 84            NaN           NaN           NaN           NaN           NaN
# 91   1.558753e+09  1.822487e+09  1.849806e+09  2.013099e+09  2.249812e+09
# 93   3.569000e+09  3.869000e+09  4.213000e+09  4.238000e+09  4.397000e+09
# 108  2.328658e+09  2.822358e+09  3.032400e+09  3.422651e+09  4.466100e+09
# 110           NaN           NaN           NaN           NaN           NaN
# 137  3.070691e+09  3.454363e+09  3.659252e+09  4.000239e+09  4.601300e+09
# 179  1.187241e+08  1.146266e+08
# 193           NaN           NaN
# 199           NaN           NaN
# 212  1.616370e+09           NaN
# 213  4.942319e+09  4.988441e+09
# 216           NaN           NaN
# 225           NaN           NaN
# 227  2.277788e+10           NaN
# 235  4.523143e+10           NaN
# 254           NaN           NaN
# 255           NaN           NaN
# 256  4.068000e+09           NaN
# 261  7.899879e+09  7.716925e+09
# 262           NaN           NaN
#
# [33 rows x 22 columns]

# %%
#Checking countries with missing GDP observations across 2001-2020
all_missing_gdp = gdp[gdp_years].isna().all(axis=1)

gdp.loc[all_missing_gdp, ['Country Name', 'Country Code']]
# Out:
#                   Country Name Country Code
# 84                   Gibraltar          GIB
# 110             Not classified          INX
# 147   St. Martin (French part)          MAF
# 193  Korea, Dem. People's Rep.          PRK
# 199           French Polynesia          PYF
# 255     British Virgin Islands          VGB

# %%
#Removing Countries with all missing GDP values from 2001-2021
gdp = gdp.loc[~all_missing_gdp].copy()

# %%
#Validate
gdp[gdp_years].isna().all(axis=1).sum()
# Out:
# np.int64(0)

# %%
#Checking year with partial missingness across 2001-2020 (at least one missigness)
any_missing_gdp = gdp[gdp_years].isna().any(axis=1)

gdp.loc[any_missing_gdp, ['Country Name'] + gdp_years]
# Out:
#                   Country Name          2001          2002          2003  \
# 0                        Aruba  1.920112e+09  1.941341e+09  2.021229e+09
# 2                  Afghanistan           NaN  4.055180e+09  4.515559e+09
# 6                      Andorra  1.546926e+09  1.755910e+09  2.361727e+09
# 11              American Samoa           NaN  5.120000e+08  5.240000e+08
# 38             Channel Islands  6.232906e+09  6.663669e+09  7.332245e+09
# 51                     Curacao           NaN           NaN           NaN
# 52              Cayman Islands           NaN           NaN           NaN
# 69                     Eritrea  7.523685e+08  7.293214e+08  8.702477e+08
# 78               Faroe Islands  1.147655e+09  1.262670e+09  1.494012e+09
# 91                   Greenland  1.086173e+09  1.169139e+09  1.558753e+09
# 93                        Guam           NaN  3.394000e+09  3.569000e+09
# 108                Isle of Man  1.659131e+09  1.947333e+09  2.328658e+09
# 137              Liechtenstein  2.491823e+09  2.688631e+09  3.070691e+09
# 149                     Monaco  2.718868e+09  2.968987e+09  3.601321e+09
# 164   Northern Mariana Islands           NaN  1.284000e+09  1.239000e+09
# 172              New Caledonia  3.297735e+09  3.740057e+09  4.915354e+09
# 179                      Nauru           NaN           NaN           NaN
# 212                 San Marino  1.077413e+09  1.168269e+09  1.464326e+09
# 213                    Somalia           NaN           NaN           NaN
# 216                South Sudan           NaN           NaN           NaN
# 225  Sint Maarten (Dutch part)           NaN           NaN           NaN
# 227       Syrian Arab Republic  8.677131e+10  9.055849e+10  9.569381e+10
# 235               Turkmenistan  3.534804e+09  4.461978e+09  5.977561e+09
# 254              Venezuela, RB  1.229040e+11  9.289359e+10  8.362063e+10
# 256      Virgin Islands (U.S.)           NaN  3.262000e+09  3.443000e+09
# 261                     Kosovo           NaN           NaN           NaN
# 262                Yemen, Rep.  9.861560e+09  1.069463e+10  1.177797e+10
#
#              2004          2005          2006          2007          2008  \
# 0    2.228492e+09  2.330726e+09  2.424581e+09  2.615084e+09  2.745251e+09
# 2    5.226779e+09  6.209138e+09  6.971286e+09  9.747880e+09  1.010931e+10
# 6    2.894922e+09  3.159905e+09  3.456442e+09  3.952601e+09  4.085631e+09
# 11   5.090000e+08  5.000000e+08  4.930000e+08  5.180000e+08  5.600000e+08
# 38   8.553643e+09  8.827273e+09  9.676173e+09  1.151461e+10           NaN
# 51            NaN           NaN           NaN           NaN           NaN
# 52            NaN           Na
# 108  7.315388e+09           NaN
# 137  6.684444e+09           NaN
# 149  7.423710e+09           NaN
# 164  1.182000e+09           NaN
# 172  9.438128e+09           NaN
# 179  1.187241e+08  1.146266e+08
# 212  1.616370e+09           NaN
# 213  4.942319e+09  4.988441e+09
# 216           NaN           NaN
# 225           NaN           NaN
# 227  2.277788e+10           NaN
# 235  4.523143e+10           NaN
# 254           NaN           NaN
# 256  4.068000e+09           NaN
# 261  7.899879e+09  7.716925e+09
# 262           NaN           NaN
#
# [27 rows x 21 columns]

# %%
#Inspecting the missigness count

missing_count_gdp = gdp[gdp_years].isna().sum(axis=1)

gdp.loc[any_missing_gdp, ['Country Name']
].assign(
    Missing_Years = missing_count_gdp[any_missing_gdp]
).sort_values(
    'Missing_Years', 
    ascending=False
)
# Out:
#                   Country Name  Missing_Years
# 38             Channel Islands             13
# 225  Sint Maarten (Dutch part)             12
# 216                South Sudan             12
# 213                    Somalia             12
# 51                     Curacao             10
# 69                     Eritrea              9
# 179                      Nauru              9
# 261                     Kosovo              7
# 254              Venezuela, RB              6
# 52              Cayman Islands              5
# 0                        Aruba              2
# 164   Northern Mariana Islands              2
# 256      Virgin Islands (U.S.)              2
# 262                Yemen, Rep.              2
# 2                  Afghanistan              1
# 172              New Caledonia              1
# 137              Liechtenstein              1
# 212                 San Marino              1
# 108                Isle of Man              1
# 93                        Guam              1
# 91                   Greenland              1
# 227       Syrian Arab Republic              1
# 235               Turkmenistan              1
# 78               Faroe Islands              1
# 11              American Samoa              1
# 6                      Andorra              1
# 149                     Monaco              1

# %% [markdown]
# Decision: Removing countries with more than 5 missing values, keeping country coverage of +75%.

# %%
# Dropping coutntries with Gpd missingness above 5
gdp = gdp.loc[missing_count_gdp <= 5].copy()

# %%
#Validate
gdp[gdp_years].isna().sum(axis=1).max()
# Out:
# np.int64(5)

# %%
#Saving cleaned preprocessed file
gdp.to_csv('Global_GDP_Cleaned.csv', index=False)

# %% [markdown]
# ### Calulating GDP mean

# %%
# Calulate the mean gdp across 2001 -2020
gdp["Mean GDP"] = gdp[gdp_years].mean(axis=1, skipna=True)

# %%
#Inspect
gdp[['Country Name', 'Mean GDP']].head()
# Out:
#                   Country Name      Mean GDP
# 0                        Aruba  2.553357e+09
# 1  Africa Eastern and Southern  7.441522e+11
# 2                  Afghanistan  1.402300e+10
# 3   Africa Western and Central  5.570494e+11
# 4                       Angola  7.868516e+10

# %%
#Saving Mean Population file
mean_gdp = gdp[['Country Name', 'Mean GDP']]

mean_gdp.to_csv('Mean_GDP_2001_2021.csv', index=False)

# %%
mean_gdp.shape
# Out:
# (251, 2)

# %% [markdown]
# ## Merging datasets 2001-2020
#
# * Mean_Population dataset: 261 country records
# * Mean_GDP: 251 country records

# %%
# Proceeding with merging the datasets
pop_gdp_analysis = pd.merge(mean_population, mean_gdp, on='Country Name',how='inner')

# %%
#Check
pop_gdp_analysis.shape
# Out:
# (247, 3)

# %%
pop_gdp_analysis.head()
# Out:
#                   Country Name  Mean Population      Mean GDP
# 0                  Afghanistan     3.021299e+07  1.402300e+10
# 1  Africa Eastern and Southern     5.321282e+08  7.441522e+11
# 2   Africa Western and Central     3.594714e+08  5.570494e+11
# 3                      Albania     2.935900e+06  1.092357e+10
# 4                      Algeria     3.685864e+07  1.454878e+11

# %%
#Validate the merge on missigness
pop_gdp_analysis.isna().sum()
# Out:
# Country Name       0
# Mean Population    0
# Mean GDP           0
# dtype: int64

# %%
#Validate the merge on duplicated countries
pop_gdp_analysis['Country Name'].duplicated().sum()
# Out:
# np.int64(0)

# %%
#Which couintries disaapeared
set(mean_population['Country Name']) - set(mean_gdp['Country Name'])
# Out:
# {'British Virgin Islands',
#  'Channel Islands',
#  'Curacao',
#  'French Polynesia',
#  'Gibraltar',
#  "Korea, Dem. People's Rep.",
#  'Kosovo',
#  'Nauru',
#  'Sint Maarten (Dutch part)',
#  'Somalia',
#  'South Sudan',
#  'St. Martin (French part)',
#  'Venezuela, RB'}

# %%
#Saving Analysis file
pop_gdp_analysis = pop_gdp_analysis[['Country Name', 'Mean Population', 'Mean GDP']]

pop_gdp_analysis.to_csv('Population_GDP_Analysis.csv', index=False)

# %% [markdown]
# Proprocessing  finished final data set contains 247 countries with Mean population and GDP.

# %% [markdown]
# ## Relationships analysis

# %% [markdown]
# ### Scatterplot

# %%
#Visualise Selling Price vs Kilometres Driven (not needed if below is available)
plt.figure(figsize=(8, 5))

sns.scatterplot(
    data=pop_gdp_analysis,
    x='Mean Population',
    y='Mean GDP'
)
plt.xlabel('Mean Population')
plt.ylabel('Mean GDP')
plt.title('Mean Population vs Mean GDP per Capita')
plt.show()

# %% [markdown]
# Most observations are concentrated at lower population means and low-to-medium mean GDP, with relatively few observations at higher values. A noticeable gap appears, and the scatterplot becomes sparse as population increases, with several extreme observations separated from the main concentrations. Overall, an upward trend appears to be present, but this requires further investigation of correlation.

# %% [markdown]
# ## Pearson Correlation

# %%
# Correlation matrix

pop_gdp_analysis[['Mean Population', 'Mean GDP']].corr(method='pearson')
# Out:
#                  Mean Population  Mean GDP
# Mean Population         1.000000  0.720367
# Mean GDP                0.720367  1.000000

# %% [markdown]
# With r = 0.719742, there is a strong positive linear correlation between mean population and mean gpd, indicating that countries with higher mean population tend to have higher mean gpd in the dataset.

# %% [markdown]
# ## Linear Regression
# * Independent variable - mean population (predictor)
# * Dependent varibale - mean GPD (target)

# %%
# Define X and y 

X = pop_gdp_analysis[['Mean Population']]
y =pop_gdp_analysis[['Mean GDP']]

# %%
# Crete and Fit the model (fitting a line through the dataset observation)
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %%
# Regression equation

print('Intercept:', model.intercept_)
print('Coefficient:', model.coef_[0])
# Out:
# Intercept: [4.69515623e+11]
# Coefficient: [6029.54535013]

# %%
# Model evalaution 

r_squared = model.score(X,y)
print('R²:',r_squared)
# Out:
# R²: 0.5189284702775676

# %% [markdown]
# Mean population accounts for approximately 52% of the variation in GDP.

# %%
# Plotting regression line
y_predict = model.predict(X)

plt.figure(figsize=(8, 5))

plt.scatter(X['Mean Population'], y, alpha=0.4)

plt.plot(
    X['Mean Population'], y_predict, color='red', linewidth=2)

plt.xlabel('Mean Population')
plt.ylabel('Mean GDP')
plt.title('Linear Regression: Mean Population vs Mean GDP per Capita')
plt.show()
